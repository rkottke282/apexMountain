# %%
pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
#
#   Downloading matplotlib-3.8.2-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.46.0-cp311-cp311-win_amd64.whl.metadata (159 kB)
#      ---------------------------------------- 0.0/159.4 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/159.4 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/159.4 kB 445.2 kB/s eta 0:00:01
#      ------------------------------------ - 153.6/159.4 kB 1.8 MB/s eta 0:00:01
#      ------------------------------------ - 153.6/159.4 kB 1.8 MB/s eta 0:00:01
#      ------------------------------------ 159.4/159.4 kB 956.2 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\reedk\workspace\apexmountain\venv\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\reedk\workspace\apexmountain\venv\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading Pillow-10.1.0-cp311-cp311-win_amd64.whl.metadata (9.6 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\reedk\workspace\apexmountain\venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\reedk\workspace\apexmountain\venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\reedk\workspace\apexmountain\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp311-cp311-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.6 MB 14.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.6 MB 10.6 MB/s eta 0:00:01
#    -------- ------------------------------- 1.5/7.6 MB 12.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.2/7.6 MB 11.7 MB/s eta 0:00:01
#    -------------- ------------------------- 2.8/7.6 MB 12.7 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/7.6 MB 13.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.3/7.6 MB 13.6 MB/s eta 0:00:01
#    ------------------------- -------------- 5.0/7.6 MB 13.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.6 MB 14.1 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.6 MB 13.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.7/7.6 MB 13.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.3/7.6 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 12.9 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.6 kB ? eta -:--:--
#    --------------------------------------- 187.6/187.6 kB 11.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.46.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------- ------------------------ 0.9/2.2 MB 18.7 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 22.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 17.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# Downloading Pillow-10.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------------- ------------------- 1.3/2.6 MB 27.7 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 22.8 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 MB 23.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 15.1 MB/s eta 0:00:00
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.46.0 kiwisolver-1.4.5 matplotlib-3.8.2 pillow-10.1.0

# %%
import tmdbsimple as tmdb
import pandas as pd
import matplotlib.pyplot as plt
tmdb.API_KEY = '77b3e44f983ea9bfc6eae8182d00e4c9'

# %%
def getActorId(name):
    id = -1
    try:
        search = tmdb.Search()
        search_results = search.person(query=name)
        id = search.results[0]['id']
    except:
        print('error')
    return id

# %%
getActorId('John Krasinski')
# Out:
# 17697

# %%
def getMovieCredits(actorId):
    person = tmdb.People(17697)
    return person.movie_credits()['cast']

# %%
movieCredits = getMovieCredits(17697)

# %%
def toDataframe(movieCredits):
    movie_credits_df = pd.DataFrame(movie_credits)
    return movie_credits_df.loc[:,('title','id','release_date', 'popularity','vote_average')].sort_values('release_date')

# %%
movie_data = toDataframe(movieCredits)

# %%
plt.plot(movie_data['release_date'], movie_data['popularity'])
plt.xticks(rotation=45)
for (i, j,k) in zip (movie_data['release_date'], movie_data['popularity'], movie_data['title']):
    plt.text(i, j, f'{k}')
plt.show()
